# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/raw/walmart.csv")
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[us]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[us](1), float64(5), int64(2)
# memory usage: 402.3 KB
#              Store                 Date  Weekly_Sales  Holiday_Flag  \
# count  6435.000000                 6435  6.435000e+03   6435.000000
# mean     23.000000  2011-06-17 00:00:00  1.046965e+06      0.069930
# min       1.000000  2010-02-05 00:00:00  2.099862e+05      0.000000
# 25%      12.000000  2010-10-08 00:00:00  5.533501e+05      0.000000
# 50%      23.000000  2011-06-17 00:00:00  9.607460e+05      0.000000
# 75%      34.000000  2012-02-24 00:00:00  1.420159e+06      0.000000
# max      45.000000  2012-10-26 00:00:00  3.818686e+06      1.000000
# std      12.988182                  NaN  5.643666e+05      0.255049
#
#        Temperature   Fuel_Price          CPI  Unemployment
# count  6435.000000  6435.000000  6435.000000   6435.000000
# mean     60.663782     3.358607   171.578394      7.999151
# min      -2.060000     2.472000   126.064000      3.879000
# 25%      47.460000     2.933000   131.735000      6.891000
# 50%      62.670000     3.445000   182.616521      7.874000
# 75%      74.940000     3.735000   212.743293      8.622000
# max     100.140000     4.468000   227.232807     14.313000
# std      18.444933     0.459020    39.356712      1.875885

# %%
plt.figure(figsize=(12,5))
plt.plot(df['Date'], df['Weekly_Sales'])
plt.title("Sales Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='Holiday_Flag', y='Weekly_Sales', data=df)
plt.title("Holiday vs Sales")
plt.show()

# %%
df['Month'] = df['Date'].dt.month

monthly_sales = df.groupby('Month')['Weekly_Sales'].mean()

monthly_sales.plot(kind='bar')
plt.title("Average Monthly Sales")
plt.show()

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Week'] = df['Date'].dt.isocalendar().week
df['Day'] = df['Date'].dt.day

# %%
df['Lag_1'] = df['Weekly_Sales'].shift(1)

# %%
df['Rolling_Mean'] = df['Weekly_Sales'].rolling(window=4).mean()

# %%
df = df.dropna()

# %%
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6432 entries, 3 to 6434
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6432 non-null   int64
#  1   Date          6432 non-null   datetime64[us]
#  2   Weekly_Sales  6432 non-null   float64
#  3   Holiday_Flag  6432 non-null   int64
#  4   Temperature   6432 non-null   float64
#  5   Fuel_Price    6432 non-null   float64
#  6   CPI           6432 non-null   float64
#  7   Unemployment  6432 non-null   float64
#  8   Month         6432 non-null   int32
#  9   Year          6432 non-null   int32
#  10  Week          6432 non-null   UInt32
#  11  Day           6432 non-null   int32
#  12  Lag_1         6432 non-null   float64
#  13  Rolling_Mean  6432 non-null   float64
# dtypes: UInt32(1), datetime64[us](1), float64(7), int32(3), int64(2)
# memory usage: 609.4 KB

# %%
X = df.drop(['Weekly_Sales', 'Date'], axis=1)
y = df['Weekly_Sales']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
# Out:
# MAE: 42274.250565034956
# MSE: 4153831594.1620517

# %%
plt.figure(figsize=(10,5))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.title("Actual vs Predicted Sales")
plt.show()

# %%
avg_demand = df['Weekly_Sales'].mean()
print("Average Demand:", avg_demand)
# Out:
# Average Demand: 1046691.7553793533

# %%
lead_time = 2  # weeks
std_dev = df['Weekly_Sales'].std()

safety_stock = 1.65 * std_dev * (lead_time ** 0.5)
print("Safety Stock:", safety_stock)
# Out:
# Safety Stock: 1316898.7586458668

# %%
reorder_point = (avg_demand * lead_time) + safety_stock
print("Reorder Point:", reorder_point)
# Out:
# Reorder Point: 3410282.2694045734

# %%
current_stock = 500000  # example

if current_stock < reorder_point:
    print("⚠️ Reorder Required")
else:
    print("✅ Stock is sufficient")
# Out:
# ⚠️ Reorder Required

# %%
print("Average Demand:", avg_demand)
print("Safety Stock:", safety_stock)
print("Reorder Point:", reorder_point)
# Out:
# Average Demand: 1046691.7553793533
# Safety Stock: 1316898.7586458668
# Reorder Point: 3410282.2694045734

# %%
current_stock = 1000000

if current_stock < reorder_point:
    print("⚠️ Reorder Required")
else:
    print("✅ Stock is sufficient")
# Out:
# ⚠️ Reorder Required

# %%
current_stock = 5000000

if current_stock < reorder_point:
    print("⚠️ Reorder Required")
else:
    print("✅ Stock is sufficient")
# Out:
# ✅ Stock is sufficient
